# %% [markdown]
# ## `Actividades preliminares`

# %% [markdown]
# Comenzamos importando la libreria de pandas

# %%
import pandas as pd

# %% [markdown]
# Cargamos el dataset que utilizaran durante la investigacion

# %%
crime_scene_report     = pd.read_csv("./datasets/Crime Scene report.csv")
drivers_license        = pd.read_csv("./datasets/Drivers license.csv")
facebook_event_checkin = pd.read_csv("./datasets/facebook_event_checkin.csv")
getfitnow_checkin      = pd.read_csv("./datasets/GetFitNow check in.csv")
getfitnow_members      = pd.read_csv("./datasets/GetFitNow members.csv")
income                 = pd.read_csv("./datasets/income.csv")
interview              = pd.read_csv("./datasets/Interviews.csv")
person                 = pd.read_csv("./datasets/Person.csv")

# %%
crime_scene_report
# Out:
#             Date       Type  \
# 0     2017-01-07  smuggling
# 1     2017-01-11     murder
# 2     2017-01-12  smuggling
# 3     2017-01-13    assault
# 4     2017-01-14  blackmail
# ...          ...        ...
# 1223  2018-04-10      arson
# 1224  2018-04-14      arson
# 1225  2018-04-17      arson
# 1226  2018-04-25      arson
# 1227  2018-04-28      arson
#
#                                             Description           City
# 0                                                   NaN       Savannah
# 1                                                   NaN     Springdale
# 2                                                   NaN      Melbourne
# 3                                                   NaN        Reading
# 4                                                   NaN         Orange
# ...                                                 ...            ...
# 1223  its head impatiently, and walked a little quic...      Santa Ana
# ...

# %%
drivers_license
# Out:
#            Id  Age  Height Eye_Color Hair_Color  Gender Plate_Number Car_Make  \
# 0      103138   37      65     brown     Blonde    Male       T6TV0T     Ford
# 1      103260   22      59     brown     Blonde  Female       G67F83     Ford
# 2      108374   18      63     brown        Red    Male       X2KE6N     Ford
# 3      109238   35      76     brown      Brown  Female       O771Z2     Ford
# 4      109596   30      75     brown        Red  Female       861GR4     Ford
# ...       ...  ...     ...       ...        ...     ...          ...      ...
# 10002  959383   39      55     amber       Blue  Female       HJM7AH     Ford
# 10003  960969   66      50     amber      White  Female       FN3TQ3     Ford
# 10004  967386   21      59     amber      White  Female       0NBT4P     Ford
# 10005  985357   84      80     amber      Green  Female       0T15Z5     Ford
# 10006  995922   77      60     amber       Blue  Female       IS2LA5     Ford
#
#                  Car_Model
# ...

# %%
facebook_event_checkin
# Out:
#        person_id  event_id                                         event_name  \
# 0          28508      5880  Nudists are people who wear one-button suits.\r\n
# 1          63713      3865  but that's because it's the best book on anyth...
# 2          63713      3999          If Murphy's Law can go wrong, it will....
# 3          63713      6436  Old programmers never die.  They just branch t...
# 4          82998      4470             Help a swallow land at Capistrano.\r\n
# ...          ...       ...                                                ...
# 20006      99716      1143                               SQL Symphony Concert
# 20007      99716      1143                               SQL Symphony Concert
# 20008      99716      1143                               SQL Symphony Concert
# 20009      67318      4719                             The Funky Grooves Tour
# 20010      67318      1143                               SQL Symphony Concert
#
#            date
# ...

# %%
getfitnow_checkin
# Out:
#      Membership_Id Check_In_Date  Check_In_Time  Check_Out_Time
# 0            NL318    2018-02-12            329             365
# 1            NL318    2017-08-11            469             920
# 2            NL318    2018-04-29            506             554
# 3            NL318    2018-01-28            124             759
# 4            NL318    2017-10-27            418            1019
# ...            ...           ...            ...             ...
# 2698         4KB72    2017-04-22           1016            1114
# 2699         4KB72    2017-06-30            408             885
# 2700         48Z7A    2018-01-09           1600            1730
# 2701         48Z55    2018-01-09           1530            1700
# 2702         90081    2018-01-09           1600            1700
#
# [2703 rows x 4 columns]

# %%
getfitnow_members
# Out:
#         Id  Person_Id               Name Membership_Start_Date  \
# 0    NL318      65076    Everette Koepke            2017-09-26
# 1    0YJ24      80651     Waneta Wellard            2017-12-06
# 2    5Y28Y      15218  Millicent Yessios            2018-02-05
# 3    A5N3S      24541       Mary Cameron            2017-05-01
# 4    R4J4S      13703         Lien Yasin            2017-04-14
# ..     ...        ...                ...                   ...
# 179  2111X      36646        Arlie Braig            2017-03-15
# 180  11ZAK      12107      Agatha Seddon            2017-06-28
# 181  HM6U8      50106        Edgar Bamba            2017-01-28
# 182  2V137      41693     Wendell Dulany            2017-12-19
# 183  4KB72      79110         Emile Hege            2017-05-22
#
#     Membership_Status
# 0                Gold
# 1                Gold
# 2                Gold
# 3                Gold
# 4                Gold
# ..                ...
# 179            Silver
# ...

# %%
income
# Out:
#             ssn  annual_income
# 0     100009868          52200
# 1     100169584          64500
# 2     100300433          74400
# 3     100355733          35900
# 4     100366269          73000
# ...         ...            ...
# 7509  999679296          54400
# 7510  999762859          77000
# 7511  999824984          82000
# 7512  999910617          82600
# 7513  999942603          11500
#
# [7514 rows x 2 columns]

# %%
interview
# Out:
#       Person_Id                                         Transcript
# 0         63713                                                NaN
# 1         33856                                                NaN
# 2         82799                                                NaN
# 3         54206                                                NaN
# 4         34615                                                NaN
# ...         ...                                                ...
# 4986      37357  Alice did not wish to offend the Dormouse agai...
# 4987      10206  time,’ she said, ‘than waste it in asking ridd...
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...
# 4990      67318  I was hired by a woman with a lot of money. I ...
#
# [4991 rows x 2 columns]

# %%
person
# Out:
#           Id                 Name  License_Id  Address_Number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       Address_Street_Name        Ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %% [markdown]
# Veamos un poco como estan conformados estos dataframes

# %%
# Usamos .info() para ver una descripcion general del dataset, como sus tipos de datos en cada columna y si presenta nulos
crime_scene_report.info()
#Podes cambiar el dataset para ver la informacion general del que quieras
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1228 entries, 0 to 1227
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         1228 non-null   object
#  1   Type         1228 non-null   object
#  2   Description  939 non-null    object
#  3   City         1228 non-null   object
# dtypes: object(4)
# memory usage: 38.5+ KB

# %%
facebook_event_checkin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20011 entries, 0 to 20010
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   person_id   20011 non-null  int64
#  1   event_id    20011 non-null  int64
#  2   event_name  20011 non-null  object
#  3   date        20011 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 625.5+ KB

# %%
crime_scene_report.head(3)
# Out:
#          Date       Type Description        City
# 0  2017-01-07  smuggling         NaN    Savannah
# 1  2017-01-11     murder         NaN  Springdale
# 2  2017-01-12  smuggling         NaN   Melbourne

# %% [markdown]
# ## `Comenzamos la investigacion`

# %% [markdown]
# ### Un crimen ha ocurrido y el detective necesita tu ayuda.

# %% [markdown]
# #### Pero antes, veamos un diagrama de esquema para ver como estan conectados todos los dataframes
#
# <img src="./_src/schemeboard.png">
#
#
# ### Te entregaron el informe del lugar del crimen, pero de alguna manera lo perdiste. Recordas vagamente que el crimen fue un ​asesinato​ que ocurrió en algún momento el ​15 de enero de 2018​ y que tuvo lugar en ​Pandas City​. **Te recomiendo comenzar por recuperar el informe correspondiente de su respectivo dataframe**

# %%
crime_scene_report
# Out:
#             Date       Type  \
# 0     2017-01-07  smuggling
# 1     2017-01-11     murder
# 2     2017-01-12  smuggling
# 3     2017-01-13    assault
# 4     2017-01-14  blackmail
# ...          ...        ...
# 1223  2018-04-10      arson
# 1224  2018-04-14      arson
# 1225  2018-04-17      arson
# 1226  2018-04-25      arson
# 1227  2018-04-28      arson
#
#                                             Description           City
# 0                                                   NaN       Savannah
# 1                                                   NaN     Springdale
# 2                                                   NaN      Melbourne
# 3                                                   NaN        Reading
# 4                                                   NaN         Orange
# ...                                                 ...            ...
# 1223  its head impatiently, and walked a little quic...      Santa Ana
# ...

# %%
# Paso 1: Buscar en informe del asesinato ocurrido en Pandas City el 2018-01-15
informe = crime_scene_report[(crime_scene_report["Date"] == "2018-01-15") & 
                            (crime_scene_report["Type"] == "murder") & (crime_scene_report["City"] == "Pandas City")]
informe
# Out:
#            Date    Type                                        Description  \
# 781  2018-01-15  murder  Security footage shows that there were 2 witne...
#
#             City
# 781  Pandas City

# %%
person
# Out:
#           Id                 Name  License_Id  Address_Number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       Address_Street_Name        Ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %%
#Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".

# %%
# Paso 2: Buscar en person los Person_Id de los dos testigos basandonos en la descripción del caso
# El testigo1 vive en la última casa de "Northwestern Dr"

# Buscar personas que viven en "Northwestern Dr"
personas_northwestern_dr = person[(person['Address_Street_Name'] == "Northwestern Dr")]
personas_northwestern_dr
# Out:
#          Id                  Name  License_Id  Address_Number  \
# 2     10010             Muoi Cary      385336             741
# 282   12711        Norman Apolito      667757             599
# 499   14887        Morty Schapiro      118009            4919
# 528   15171          Weldon Penso      336999             311
# 811   17729        Lasonya Wildey      439686            3824
# 904   18376              Josh Shi      653712            1091
# 1021  19420           Cody Schiel      890431            3524
# 1338  22239         Dusty Sigafus      710517            1125
# 1426  23044          Val Portlock      924989            3143
# 1522  23960  Kristopher Lagerberg      658777            1392
# 1686  25615         Olevia Morena      388477             812
# 1812  26758      Angelena Billman      942074             629
# 1981  28360        Rashad Cascone      924517            3212
# 2131  29608       Willetta Lurvey      800568            1028
# ...

# %%
# Buscar persona que vive en la última casa de "Northwestern Dr"
indice_max_numero_direccion = personas_northwestern_dr['Address_Number'].idxmax()
persona_ultima_casa = personas_northwestern_dr.loc[indice_max_numero_direccion]

persona_ultima_casa
# Out:
# Id                               14887
# Name                    Morty Schapiro
# License_Id                      118009
# Address_Number                    4919
# Address_Street_Name    Northwestern Dr
# Ssn                          111564949
# Name: 499, dtype: object

# %%
# El testigo2 se llama Annabel y vive en "Franklin Ave"

# Buscar personas que viven en "Franklin Ave"
personas_franklin_ave = person[(person['Address_Street_Name'] == "Franklin Ave")]
personas_franklin_ave
# Out:
#          Id                 Name  License_Id  Address_Number  \
# 235   12207       Wilmer Wolever      509484             139
# 665   16371       Annabel Miller      490173             103
# 807   17683        Johnnie Schee      968887            1277
# 936   18651        Carleen Etoll      356746              22
# 1377  22636       Zachary Ybarbo      768359             785
# 1608  24737           Gema Nantz      273410            3968
# 2236  30654      Clarita Rickels      418084            2254
# 2427  32264       Shelby Dezeeuw      735415            1391
# 2584  33793         Amado Mattan      161915              99
# 2661  34592    Cordell Lindamood      592762            3657
# 2864  36328         Domenic Laun      971080            3809
# 2877  36400         Noe Pancoast      895755            3443
# 3009  37616     Katelyn Schwerin      430143             332
# 4086  46827         Bev Billiter      643591            2316
# ...

# %%
#Buscar Annabel en el grupo de personas que viven en "Franklin Ave"
# Buscar a una persona llamada Annabel
persona_annabel = personas_franklin_ave.loc[personas_franklin_ave['Name'].str.contains('Annabel')]
persona_annabel
# Out:
#         Id            Name  License_Id  Address_Number Address_Street_Name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            Ssn
# 665  318771143

# %%
interview
# Out:
#       Person_Id                                         Transcript
# 0         63713                                                NaN
# 1         33856                                                NaN
# 2         82799                                                NaN
# 3         54206                                                NaN
# 4         34615                                                NaN
# ...         ...                                                ...
# 4986      37357  Alice did not wish to offend the Dormouse agai...
# 4987      10206  time,’ she said, ‘than waste it in asking ridd...
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...
# 4990      67318  I was hired by a woman with a lot of money. I ...
#
# [4991 rows x 2 columns]

# %%
# Paso 3: Buscar en interview los Person_Id identificados en el Paso 2
# El Person_Id del testigo1 es 14887
entrevista_testigo1 = interview[(interview['Person_Id'] == 14887)]
entrevista_testigo1
# Out:
#       Person_Id                                         Transcript
# 4988      14887  I heard a gunshot and then saw a man run out. ...

# %%
#I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".

# %%
# Paso 3: Buscar en interview los Person_Id identificados en el Paso 2
# El Person_Id del testigo2 es 16371
entrevista_testigo2 = interview[(interview['Person_Id'] == 16371)]
entrevista_testigo2
# Out:
#       Person_Id                                         Transcript
# 4989      16371  I saw the murder happen, and I recognized the ...

# %%
#I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %%
getfitnow_checkin
# Out:
#      Membership_Id Check_In_Date  Check_In_Time  Check_Out_Time
# 0            NL318    2018-02-12            329             365
# 1            NL318    2017-08-11            469             920
# 2            NL318    2018-04-29            506             554
# 3            NL318    2018-01-28            124             759
# 4            NL318    2017-10-27            418            1019
# ...            ...           ...            ...             ...
# 2698         4KB72    2017-04-22           1016            1114
# 2699         4KB72    2017-06-30            408             885
# 2700         48Z7A    2018-01-09           1600            1730
# 2701         48Z55    2018-01-09           1530            1700
# 2702         90081    2018-01-09           1600            1700
#
# [2703 rows x 4 columns]

# %%
# Paso 4: Buscar en getfitnow_checkin las personas que ingresaron al gimnasio el 2018-01-09
# Filtrar las filas donde la columna 'Check_In_Date' sea '2018-01-09'
personas_ingreso_2018_01_09 = getfitnow_checkin[getfitnow_checkin['Check_In_Date'] == '2018-01-09']

personas_ingreso_2018_01_09
# Out:
#      Membership_Id Check_In_Date  Check_In_Time  Check_Out_Time
# 113          X0643    2018-01-09            957            1164
# 889          UK1F2    2018-01-09            344             518
# 1329         XTE42    2018-01-09            486            1124
# 1446         1AE2H    2018-01-09            461             944
# 1703         6LSTG    2018-01-09            399             515
# 2137         7MWHJ    2018-01-09            273             885
# 2435         GE5Q8    2018-01-09            367             959
# 2700         48Z7A    2018-01-09           1600            1730
# 2701         48Z55    2018-01-09           1530            1700
# 2702         90081    2018-01-09           1600            1700

# %%
# Paso 5: Buscar en personas_ingreso_2018_01_09 las Membership_Id que empiezan con '48Z'

# Filtrar las filas donde la columna 'Membership_Id' empieza con '48Z'
miembros_48Z = personas_ingreso_2018_01_09[personas_ingreso_2018_01_09['Membership_Id'].str.startswith('48Z')]

# Mostrar los resultados
miembros_48Z
# Out:
#      Membership_Id Check_In_Date  Check_In_Time  Check_Out_Time
# 2700         48Z7A    2018-01-09           1600            1730
# 2701         48Z55    2018-01-09           1530            1700

# %%
getfitnow_members
# Out:
#         Id  Person_Id               Name Membership_Start_Date  \
# 0    NL318      65076    Everette Koepke            2017-09-26
# 1    0YJ24      80651     Waneta Wellard            2017-12-06
# 2    5Y28Y      15218  Millicent Yessios            2018-02-05
# 3    A5N3S      24541       Mary Cameron            2017-05-01
# 4    R4J4S      13703         Lien Yasin            2017-04-14
# ..     ...        ...                ...                   ...
# 179  2111X      36646        Arlie Braig            2017-03-15
# 180  11ZAK      12107      Agatha Seddon            2017-06-28
# 181  HM6U8      50106        Edgar Bamba            2017-01-28
# 182  2V137      41693     Wendell Dulany            2017-12-19
# 183  4KB72      79110         Emile Hege            2017-05-22
#
#     Membership_Status
# 0                Gold
# 1                Gold
# 2                Gold
# 3                Gold
# 4                Gold
# ..                ...
# 179            Silver
# ...

# %%
# Paso 6: Buscar en getfitnow_members el id de las personas que aparecen en miembros_48Z
# id persona1
id_persona1 = '48Z7A'
persona1 = getfitnow_members[getfitnow_members['Id'] == id_persona1]
persona1
# Out:
#        Id  Person_Id          Name Membership_Start_Date Membership_Status
# 65  48Z7A      28819  Joe Germuska            2016-03-05              Gold

# %%
# id persona2
id_persona2 = '48Z55'
persona2 = getfitnow_members[getfitnow_members['Id'] == id_persona2]
persona2
# Out:
#        Id  Person_Id           Name Membership_Start_Date Membership_Status
# 66  48Z55      67318  Jeremy Bowers            2016-01-01              Gold

# %%
# Paso 7: Buscar en person el nombre de la persona1 y la persona2
nombre_persona1 = 'Joe Germuska'
fila_persona1 = person[person['Name'] == nombre_persona1]
fila_persona1
# Out:
#          Id          Name  License_Id  Address_Number Address_Street_Name  \
# 2037  28819  Joe Germuska      173289             111             Fisk Rd
#
#             Ssn
# 2037  138909730

# %%
nombre_persona2 = 'Jeremy Bowers'
fila_persona2 = person[person['Name'] == nombre_persona2]
fila_persona2
# Out:
#          Id           Name  License_Id  Address_Number    Address_Street_Name  \
# 6327  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#             Ssn
# 6327  871539279

# %%
# Paso 8: Buscar en drivers_license los License_Id
license_id_persona1 = 173289
fila_license_persona1 = drivers_license[drivers_license['Id'] == license_id_persona1]
fila_license_persona1
# Out:
# Empty DataFrame
# Columns: [Id, Age, Height, Eye_Color, Hair_Color, Gender, Plate_Number, Car_Make, Car_Model]
# Index: []

# %%
license_id_persona2 = 423327
fila_license_persona2 = drivers_license[drivers_license['Id'] == license_id_persona2]
fila_license_persona2
# Out:
#          Id  Age  Height Eye_Color Hair_Color Gender Plate_Number   Car_Make  \
# 204  423327   30      70     brown      Brown   Male       0H42W2  Chevrolet
#
#     Car_Model
# 204  Spark LS

# %% [markdown]
# ## Si creen que encontraron al asesino, ejecuten el siguiente codigo con el posible sospechoso
#
#  Por favor, tene en cuenta que es recomendable no acceder al archivo "asesino.py" para evitar revelar detalles importantes de la caso. Si deseas disfrutar plenamente de la experiencia sin spoilers, te sugiero que evites examinar dicho archivo."

# %%
from asesino import solucion
solucion("Jeremy Bowers")
# Out:
# ¡Felicidades, encontraste al asesino! Pero espera, hay más...
#  Si crees que estas preparado para un desafío, segui investigando
#  la transcripcion del asesino para encontrar al verdadero villano detrás de este crimen

# %%
interview
# Out:
#       Person_Id                                         Transcript
# 0         63713                                                NaN
# 1         33856                                                NaN
# 2         82799                                                NaN
# 3         54206                                                NaN
# 4         34615                                                NaN
# ...         ...                                                ...
# 4986      37357  Alice did not wish to offend the Dormouse agai...
# 4987      10206  time,’ she said, ‘than waste it in asking ridd...
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...
# 4990      67318  I was hired by a woman with a lot of money. I ...
#
# [4991 rows x 2 columns]

# %%
#Paso 10: Buscar en interview el Person_Id de Jeremy Bowers y leer la transcripción de la entrevista
person_id_jeremy_bowers = 67318
asesino = interview[interview['Person_Id'] == person_id_jeremy_bowers]
asesino
# Out:
#       Person_Id                                         Transcript
# 4990      67318  I was hired by a woman with a lot of money. I ...

# %%
# Transcripción: "I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017."

# %%
drivers_license
# Out:
#            Id  Age  Height Eye_Color Hair_Color  Gender Plate_Number Car_Make  \
# 0      103138   37      65     brown     Blonde    Male       T6TV0T     Ford
# 1      103260   22      59     brown     Blonde  Female       G67F83     Ford
# 2      108374   18      63     brown        Red    Male       X2KE6N     Ford
# 3      109238   35      76     brown      Brown  Female       O771Z2     Ford
# 4      109596   30      75     brown        Red  Female       861GR4     Ford
# ...       ...  ...     ...       ...        ...     ...          ...      ...
# 10002  959383   39      55     amber       Blue  Female       HJM7AH     Ford
# 10003  960969   66      50     amber      White  Female       FN3TQ3     Ford
# 10004  967386   21      59     amber      White  Female       0NBT4P     Ford
# 10005  985357   84      80     amber      Green  Female       0T15Z5     Ford
# 10006  995922   77      60     amber       Blue  Female       IS2LA5     Ford
#
#                  Car_Model
# ...

# %%
# Definir variables que aparecen en la transcripción
color = 'Red'
marca_auto = 'Tesla'
modelo_auto = 'Model S'

# Buscar el color de pelo y la marca y modelo del auto en drivers_license
actor_intelectual = drivers_license.loc[(drivers_license['Hair_Color'] == color) & 
                                        (drivers_license['Car_Make'] == marca_auto) & 
                                        (drivers_license['Car_Model'] == modelo_auto)]
actor_intelectual
# Out:
#           Id  Age  Height Eye_Color Hair_Color  Gender Plate_Number Car_Make  \
# 827   736081   79      69     brown        Red    Male       GCAQ6Y    Tesla
# 2291  291182   65      66      blue        Red  Female       08CM64    Tesla
# 4898  918773   48      65     black        Red  Female       917UU3    Tesla
# 6883  202298   68      66     green        Red  Female       500123    Tesla
#
#      Car_Model
# 827    Model S
# 2291   Model S
# 4898   Model S
# 6883   Model S

# %%
# Buscar el Id de una persona con una altura entre 65 y 67
# Método 1
resultado = actor_intelectual.loc[(actor_intelectual['Height'] >= 65) & 
                                  (actor_intelectual['Height'] <= 67)]
resultado
# Out:
#           Id  Age  Height Eye_Color Hair_Color  Gender Plate_Number Car_Make  \
# 2291  291182   65      66      blue        Red  Female       08CM64    Tesla
# 4898  918773   48      65     black        Red  Female       917UU3    Tesla
# 6883  202298   68      66     green        Red  Female       500123    Tesla
#
#      Car_Model
# 2291   Model S
# 4898   Model S
# 6883   Model S

# %%
# Buscar el Id de una persona con una altura entre 65 y 67
# Método 2

altura_min = 65
altura_max = 67

rango_altura = actor_intelectual.loc[
    (actor_intelectual['Height'] >= altura_min) & 
    (actor_intelectual['Height'] <= altura_max)
]
rango_altura
# Out:
#           Id  Age  Height Eye_Color Hair_Color  Gender Plate_Number Car_Make  \
# 2291  291182   65      66      blue        Red  Female       08CM64    Tesla
# 4898  918773   48      65     black        Red  Female       917UU3    Tesla
# 6883  202298   68      66     green        Red  Female       500123    Tesla
#
#      Car_Model
# 2291   Model S
# 4898   Model S
# 6883   Model S

# %%
facebook_event_checkin
# Out:
#        person_id  event_id                                         event_name  \
# 0          28508      5880  Nudists are people who wear one-button suits.\r\n
# 1          63713      3865  but that's because it's the best book on anyth...
# 2          63713      3999          If Murphy's Law can go wrong, it will....
# 3          63713      6436  Old programmers never die.  They just branch t...
# 4          82998      4470             Help a swallow land at Capistrano.\r\n
# ...          ...       ...                                                ...
# 20006      99716      1143                               SQL Symphony Concert
# 20007      99716      1143                               SQL Symphony Concert
# 20008      99716      1143                               SQL Symphony Concert
# 20009      67318      4719                             The Funky Grooves Tour
# 20010      67318      1143                               SQL Symphony Concert
#
#             date
# ...

# %%
# Cambiar el formato de la fecha en facebook_event_checkin
facebook_event_checkin['date'] = pd.to_datetime(facebook_event_checkin['date'], format='%Y%m%d')
facebook_event_checkin
# Out:
#        person_id  event_id                                         event_name  \
# 0          28508      5880  Nudists are people who wear one-button suits.\r\n
# 1          63713      3865  but that's because it's the best book on anyth...
# 2          63713      3999          If Murphy's Law can go wrong, it will....
# 3          63713      6436  Old programmers never die.  They just branch t...
# 4          82998      4470             Help a swallow land at Capistrano.\r\n
# ...          ...       ...                                                ...
# 20006      99716      1143                               SQL Symphony Concert
# 20007      99716      1143                               SQL Symphony Concert
# 20008      99716      1143                               SQL Symphony Concert
# 20009      67318      4719                             The Funky Grooves Tour
# 20010      67318      1143                               SQL Symphony Concert
#
#             date
# ...

# %%
# Definir las fechas como strings
fecha_min = "2017-12-01"
fecha_max = "2017-12-31"

# Convertir las fechas a datetime
fecha_min = pd.to_datetime(fecha_min)
fecha_max = pd.to_datetime(fecha_max)

# Filtrar el DataFrame por rango de fechas
rango_fecha = facebook_event_checkin.loc[
    (facebook_event_checkin['date'] >= fecha_min) & 
    (facebook_event_checkin['date'] <= fecha_max)
]

rango_fecha
# Out:
#        person_id  event_id                                         event_name  \
# 7          31811      8542                            -- Herbert Prochnow\r\n
# 19         41421      3799             And everywhere this language went,\r\n
# 27         66493       816  Just because your doctor has a name for your c...
# 52         96520      8784  Good advice is something a man gives when he i...
# 59         33355      1973                           He sure is a fun god\r\n
# ...          ...       ...                                                ...
# 20003      24556      1143                               SQL Symphony Concert
# 20006      99716      1143                               SQL Symphony Concert
# 20007      99716      1143                               SQL Symphony Concert
# 20008      99716      1143                               SQL Symphony Concert
# 20010      67318      1143                               SQL Symphony Concert
#
#             date
# ...

# %%
##Paso 15: ## Filtrar facebook_event_checkin por rango de fechas y nombre del evento
evento_nombre = "SQL Symphony Concert"
rango_fecha_evento = facebook_event_checkin.loc[
    (facebook_event_checkin['date'] >= fecha_min) &
    (facebook_event_checkin['date'] <= fecha_max) &
    (facebook_event_checkin['event_name'].str.contains(evento_nombre))
]
rango_fecha_evento
# Out:
#        person_id  event_id            event_name       date
# 4087       62596      1143  SQL Symphony Concert 2017-12-25
# 4392       19260      1143  SQL Symphony Concert 2017-12-14
# 6552       58898      1143  SQL Symphony Concert 2017-12-20
# 6620       69699      1143  SQL Symphony Concert 2017-12-14
# 6717       19292      1143  SQL Symphony Concert 2017-12-13
# 7266       43366      1143  SQL Symphony Concert 2017-12-07
# 8395       92343      1143  SQL Symphony Concert 2017-12-12
# 10909      28582      1143  SQL Symphony Concert 2017-12-20
# 10910      28582      1143  SQL Symphony Concert 2017-12-15
# 13719      81526      1143  SQL Symphony Concert 2017-12-02
# 13745      24397      1143  SQL Symphony Concert 2017-12-08
# 14312      11173      1143  SQL Symphony Concert 2017-12-23
# 15305      79312      1143  SQL Symphony Concert 2017-12-03
# 15896      69325      1143  SQL Symphony Concert 2017-12-06
# 20001      24556      1143  SQL Symphony Concert 2017-12-07
# ...

# %%
# Paso 16: Identificar el person_id de las personas que hayan asistido 3 veces al evento 'SQL Symphony Concert'
conteo_person_id = evento_filtrado['person_id'].value_counts()
conteo_person_id_3_veces = conteo_person_id.loc[conteo_person_id == 3]
conteo_person_id_3_veces
# Out:
# person_id
# 24556    3
# 99716    3
# Name: count, dtype: int64

# %%
# Paso 17: Buscar en person el Id de la primera persona que aparece en conteo_person_id_3_veces
person_id_persona1 = 24556
persona1 = person[person['Id'] == person_id_persona1]
persona1
# Out:
#          Id         Name  License_Id  Address_Number Address_Street_Name  \
# 1587  24556  Bryan Pardo      101191             703          Machine Ln
#
#             Ssn
# 1587  816663882

# %%
# Paso 18: Buscar en person el Id de la segunda persona que aparece en conteo_person_id_3_veces
person_id_persona2 = 99716
persona2 = person[person['Id'] == person_id_persona2]
persona2
# Out:
#          Id              Name  License_Id  Address_Number Address_Street_Name  \
# 9985  99716  Miranda Priestly      202298            1883          Golden Ave
#
#             Ssn
# 9985  987756388

# %%
# Paso 19: Buscar en drivers_license el Id de Miranda Priestly dado que la sospechosa es mujer para verificar que cumpla con la transcripción de la declaración del asesino:  "I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017."
license_id_persona2 = 202298
licencia_pesona2 = drivers_license[drivers_license['Id'] == license_id_persona2]
licencia_pesona2
# Out:
#           Id  Age  Height Eye_Color Hair_Color  Gender Plate_Number Car_Make  \
# 6883  202298   68      66     green        Red  Female       500123    Tesla
#
#      Car_Model
# 6883   Model S
